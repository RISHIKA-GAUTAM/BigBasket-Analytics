# %% [markdown]
# ## <center> <u> **BigBasket Analytics: Unlocking the Power of Data in E-Commerce** </u> </center>
# >

# %% [markdown]
# ### ![image.png](attachment:710dc8cd-06d5-4473-8165-7e1ba89dbb1a.png)

# %% [markdown]
# ### BigBasket Overview
# - **BigBasket** is India’s top online grocery retailer, providing a vast range of products such as fresh fruits and vegetables, meat, dairy, bakery items, and other household essentials. With a strong supply chain and partnerships with local farmers.
# - BigBasket guarantees fresh and high-quality products.
# - Customers can shop conveniently through its website or mobile app, with options for various payment methods and flexible delivery services.
# -  BigBasket also offers exclusive benefits through its BB Star membership, making it a preferred choice for online grocery shopping in India.
#
# ### Problem Statement
# - The rapid growth of e-commerce platforms like BigBasket has introduced challenges in managing large-scale operations, inventory optimization, and customer satisfaction. The objective is to analyze BigBasket's operational data to uncover trends, improve efficiency, and enhance decision-making for better business outcomes.
#
# ### Goal
# - To conduct an in-depth analysis of BigBasket's data to identify areas for process improvement, optimize inventory management, and ensure high customer satisfaction through data-driven strategies.
#
# ### Dataset Summary
# - **index**: A unique integer identifier for each observation.
# - **product**: The name of the product (text format).
# - **category**: The primary category or department the product belongs to (e.g., “Beauty & Hygiene,” “Kitchen, Garden & Pets”).
# - **sub_category**: A more specific classification within the main category (e.g., “Hair Care,” “Storage & Accessories”).
# - **brand**: The brand name of the product (text format).
# - **sale_price**: The selling price of the product (numerical).
# - **market_price**: The original or market-listed price of the product (numerical).
# - **rating**: The customer satisfaction score for the product (numerical).
# - **description**: Additional details or description of the product (text format).

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import plotly.io as pio

# %% [markdown]
# ### Step 1: Load DataSet

# %%
df = pd.read_csv("C:/Users/DELL-/Downloads/BigBasket Products.csv")
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# ### Step 2:look for first 12 rows.

# %%
df.head(10)
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
# 5      6                  Germ - Removal Multipurpose Wipes
# 6      7                                       Multani Mati
# 7      8                  Hand Sanitizer - 70% Alcohol Base
# 8      9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9     10               Scrub Pad - Anti- Bacterial, Regular
#
#                  category            sub_category              brand  \
# 0        Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets   Storage & Accessories         Mastercook
# 2    Cleaning & Household             Pooja Needs                Trm
# ...

# %% [markdown]
# ### Step 3: Get Description of the data in the DataFrame.

# %%
df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %% [markdown]
# ### Step 4: Find Information about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Step 5: Find out Top & least sold products

# %%
#top product
df[['product','category','sub_category']].value_counts().head(1)
# Out:
# product                       category                  sub_category
# Turmeric Powder/Arisina Pudi  Foodgrains, Oil & Masala  Masalas & Spices    25
# Name: count, dtype: int64

# %%
#least sold product
df[['product','category','sub_category']].value_counts().tail(1)
# Out:
# product                             category              sub_category
# 1 To 1  Baking Flour - Gluten Free  Gourmet & World Food  Cooking & Baking Needs    1
# Name: count, dtype: int64

# %% [markdown]
# ## Step 6: Measuring discount on a certain item.

# %%
discount=(df['market_price']-df['sale_price'])/df['market_price']*100
discount
# Out:
# 0         0.000000
# 1         0.000000
# 2        52.400000
# 3        15.340909
# 4         0.000000
#            ...
# 27550    20.000000
# 27551    10.000000
# 27552     0.000000
# 27553    20.000000
# 27554    44.992308
# Length: 27555, dtype: float64

# %% [markdown]
# ### Step 7: Find out the Missing Values from the Dataset.

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
df[df['product'].isna()]
# Out:
#       product   category sub_category          brand  sale_price  \
# index
# 14364     NaN  Beverages       Coffee  Cothas Coffee       200.0
#
#        market_price           type  rating  \
# index
# 14364         240.0  Ground Coffee     4.2
#
#                                              description
# index
# 14364  Cothas Specialty Blend Coffee and Chicory incl...

# %%
df[df['brand'].isna()]
# Out:
#                      product              category              sub_category  \
# index
# 9766   Food Package - Medium  Cleaning & Household  Disposables, Garbage Bag
#
#       brand  sale_price  market_price                       type    rating  \
# index
# 9766    NaN        50.0          50.0  Aluminium Foil, Clingwrap  3.956482
#
#       description
# index
# 9766          NaN

# %% [markdown]
# ### Find out the percentage of missing values of dataset

# %%
total_missing_values=missing_values.sum()
total_cell=np.prod(df.shape)
percent_missing = (total_missing_values/total_cell) * 100
print("Percentage: {:.2f}%".format(percent_missing))
# Out:
# Percentage: 0.42%

# %% [markdown]
# ### Cleaning missing values

# %%
df2=pd.DataFrame(df)

# %%
df2.loc[df2['product'].isna(),'product']='Unknown'
df2['product']
# Out:
# 0                   Garlic Oil - Vegetarian Capsule 500 mg
# 1                                    Water Bottle - Orange
# 2                           Brass Angle Deep - Plain, No.2
# 3        Cereal Flip Lid Container/Storage Jar - Assort...
# 4                       Creme Soft Soap - For Hands & Body
#                                ...
# 27550           Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                             Rosemary
# 27552                         Peri-Peri Sweet Potato Chips
# 27553                            Green Tea - Pure Original
# 27554                       United Dreams Go Far Deodorant
# Name: product, Length: 27555, dtype: object

# %%
df2.loc[df2['description'].isna(),'description']='Unknown'
df2['description']
# Out:
# 0        This Product contains Garlic Oil that is known...
# 1        Each product is microwave safe (without lid), ...
# 2        A perfect gift for all occasions, be it your m...
# 3        Multipurpose container with an attractive desi...
# 4        Nivea Creme Soft Soap gives your skin the best...
#                                ...
# 27550    Layerr brings you Wottagirl Classic fragrant b...
# 27551    Puramate rosemary is enough to transform a dis...
# 27552    We have taken the richness of Sweet Potatoes (...
# 27553    Tetley Green Tea with its refreshing pure, ori...
# 27554    The new mens fragrance from the United Dreams ...
# Name: description, Length: 27555, dtype: object

# %%
df2.loc[df2['brand'].isna(),'brand']='Unknown'
df2['brand']
# Out:
# 0                 Sri Sri Ayurveda
# 1                        Mastercook
# 2                               Trm
# 3                            Nakoda
# 4                             Nivea
#                     ...
# 27550                        Layerr
# 27551                      Puramate
# 27552                        FabBox
# 27553                        Tetley
# 27554    United Colors Of Benetton
# Name: brand, Length: 27555, dtype: object

# %%
df2['rating'].median()
# Out:
# np.float64(4.1)

# %%
df2['sale_price'] = np.where(df2['sale_price'].isna(),df2['sale_price'].median(), df2['sale_price'])
df2['sale_price']
# Out:
# 0        220.00
# 1        180.00
# 2        119.00
# 3        149.00
# 4        162.00
#           ...
# 27550    199.20
# 27551     67.50
# 27552    200.00
# 27553    396.00
# 27554    214.53
# Name: sale_price, Length: 27555, dtype: float64

# %%
df2['rating'] = np.where(df2['rating'].isna(),df2['rating'].median(), df2['rating'])
df2['rating']
# Out:
# 0        4.1
# 1        2.3
# 2        3.4
# 3        3.7
# 4        4.4
#         ...
# 27550    3.9
# 27551    4.0
# 27552    3.8
# 27553    4.2
# 27554    4.5
# Name: rating, Length: 27555, dtype: float64

# %% [markdown]
# ### Data after cleaning

# %%
df2.isna().sum()
# Out:
# index           0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %% [markdown]
# ### Step 8: Find out the outliers from the dataset according to the columns

# %%
# List of specific columns to plot
columns_to_plot = ['sale_price', 'market_price', 'rating']

# Plot box plots for the selected columns
plt.figure(figsize=(5, len(columns_to_plot) * 3))  # Adjust figure size
for i, column in enumerate(columns_to_plot):
    plt.subplot(len(columns_to_plot), 1, i + 1)
    sns.boxplot(x=df2[column])
    plt.title(f'Box Plot of {column} before treating Outliers')
    plt.tight_layout()

plt.show()

# %%
def replace_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_bound = max(Q1 - 1.5 * IQR,0)
    upper_bound = Q3 + 1.5 * IQR
    
    # Replace values below lower bound with lower bound and values above upper bound with upper bound
    data[column] = data[column].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))
    
    return data

data = replace_outliers(df2, 'sale_price')
data = replace_outliers(df2, 'market_price')
data = replace_outliers(df2, 'rating')

# %%
# List of specific columns to plot
columns_to_plot = ['sale_price', 'market_price', 'rating']

# Plot box plots for the selected columns
plt.figure(figsize=(5, len(columns_to_plot) * 3))  # Adjust figure size
for i, column in enumerate(columns_to_plot):
    plt.subplot(len(columns_to_plot), 1, i + 1)
    sns.boxplot(x=df2[column])
    plt.title(f'Box Plot of {column} after treating Outliers')
    plt.tight_layout()

plt.show()

# %% [markdown]
# ### Step 9: Create Plots or visualizations.

# %% [markdown]
# <h2>Top 5 Products by Rating</h2>

# %%
top_5_products = df2.nlargest(7, 'rating')[['product', 'rating']]
plt.bar(top_5_products['product'], top_5_products['rating'], color='green')
plt.xlabel('Product')
plt.ylabel('Rating')
plt.title('Top 5 Products by Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>Uniform Ratings:</b> All five products displayed in the graph have received a rating of 4 out of 4, indicating that they are highly favored by consumers.</li>
#     <li><b>Product Categories:</b> The products span different categories, including food (Extra Fine Green Peas, Millet Rusk - Sweet, Ragi Flakes) and personal care (Olive Oil - Classic, Yang Ylang Essential Oil, Wonderz Milk Shakes - Classic Vanilla, Sun Expert Fairness Sunscreen Lotion SPF 30 PA+++). This variety suggests that the top-rated items cater to both nutritional and skincare needs.</li>
#     <li><b>Consumer Satisfaction:</b> The perfect ratings of these products likely reflect strong overall customer satisfaction, suggesting high quality, effectiveness, and positive consumer experiences.</li>
#     <li><b>Marketing and Popularity:</b> Given their top-tier ratings, these products may have strong market visibility and effective marketing strategies, contributing to their popularity among consumers.</li>
#     <li><b>Potential for Recommendations:</b> The high ratings indicate that these products could be recommended to potential buyers, as they represent some of the best options available in their respective categories.</li>
# </ol>

# %% [markdown]
# ### Brand Ratings

# %%
brand_ratings = df2.groupby('brand')['rating'].mean().reset_index().head(20)
brand_ratings_sorted = brand_ratings.sort_values(by='rating', ascending=False)
plt.figure(figsize=(10,6))
plt.plot(brand_ratings_sorted['brand'], brand_ratings_sorted['rating'], marker='*', color='green')
plt.xticks(rotation=90)
plt.xlabel('Brand')
plt.ylabel('Average Rating')
plt.title('Average Rating of top Brands')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>High Initial Ratings:</b> The graph shows that the brands "A&M" and "7 Up" have the highest average ratings, slightly above 4.25. This suggests strong consumer satisfaction in those brands.</li>
#     <li><b>Gradual Decline:</b> There is a noticeable downward trend in average ratings as we move from the top-rated brands to the lower-rated ones. The ratings gradually decrease from around 4.25 to below 4.00, especially for brands towards the end.</li>
#     <li><b>Steep Drop Between Brands:</b> The most significant drop occurs after the first few brands (specifically between "Roses" and "50 Ap"), indicating a notable gap in consumer satisfaction.</li>
#     <li><b>Mid-Tier Brands:</b> Brands like "9g," "1st Bites," and "365" maintain an average rating around 4.10. These brands are performing moderately well but are below the top tier.</li>
#     <li><b>Lower Ratings at the Bottom:</b> The brands towards the end of the list, such as "6 Rasa" and "&Me," have an average rating closer to 3.95, indicating a lower level of consumer satisfaction and potentially signaling areas for improvement.</li>
#     <li><b>Potential Analysis of Consumer Preferences:</b> The trend suggests that consumers have strong preferences for certain brands, which may be influenced by factors such as quality, price, marketing, or product variety.</li>
# </ol>

# %% [markdown]
# ### Price Distribution (histogram)

# %%
plt.figure(figsize=(10, 6))  

# Increase the number of bins, e.g., to 40  
plt.hist(df2['sale_price'], bins=40, color='green', edgecolor='black')  
plt.yscale('log')  # Use logarithmic scale for the y-axis  
plt.title('Distribution of Sales Price')  
plt.xlabel('Sale Price')  
plt.ylabel('Log Frequency')  

plt.xlim(0, 12000)  
plt.xticks(range(0, 13000, 2000))  

plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>Right-Skewed Distribution:</b> The histogram illustrates a right-skewed distribution of sales prices, with a concentration of sales occurring at lower price points.</li>
#     <li><b>High Frequency in Lowest Range:</b> The first bin (0 to 2000) has a significantly high log frequency (over 10,000), indicating that a large volume of sales occurs at lower prices. This suggests that most products are priced affordably.</li>
#     <li><b>Decrease in Frequency:</b> As the sales price increases beyond 2000, there is a noticeable decline in the frequency of sales. The frequency drops substantially in the 2000 to 4000 range, indicating fewer transactions at mid-range prices.</li>
#     <li><b>Minimal High Price Sales:</b> Very few sales occur at prices above 8000. The bins for higher price ranges (8000 to 12000) have much lower frequencies, signaling a lack of consumer purchases at these levels.</li>
#     <li><b>Potential Market Insights:</b> The distribution suggests that the majority of consumers may prefer lower-priced items, which could influence pricing strategies and marketing efforts for businesses. It may indicate a price-sensitive market.</li>
#     <li><b>Implications for Inventory:</b> Retailers might want to focus more on the lower-priced products to align with consumer purchasing behavior, possibly considering the introduction of additional mid-range options to capture more of the market.</li>
# </ol>

# %% [markdown]
# ### Scatter plot of sale price vs rating

# %%
plt.figure(figsize=(8,6))
plt.scatter(df2['sale_price'], df2['rating'], color='blue', alpha=0.6)
plt.title('Sale Price vs Rating')
plt.xlabel('Sale Price')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>Clusters at Lower Ratings:</b> The majority of ratings are concentrated between 1.0 and 4.5, indicating that most products have relatively low to moderate consumer ratings.</li>
#     <li><b>High Frequency of Lower Sale Prices:</b> There is a dense cluster of points at lower sale prices, particularly between 0 and 20,000. This suggests that most sales occur at these lower price points.
#
# </li>
#     <li><b>Few High Rated Products:</b> Only a few products have higher ratings (4.5 to 5.0). This indicates that top-rated products are relatively rare among the offerings.</li>
#     <li><b>Outliers at Higher Sale Prices:</b> There are a couple of products with significantly high sale prices (above 60,000) but still low ratings (around 2.0). This suggests that high price does not necessarily correlate with high ratings.</li>
#     <li><b>Potential Lack of Correlation:</b> The spread indicates a possible lack of strong correlation between sale price and rating. Products are priced low with varying ratings, suggesting that factors other than price may influence customer satisfaction.</li>
#     <li><b>Implications for Pricing Strategy:</b> Businesses might consider reviewing the quality and features of lower-rated products, especially those at lower price points, to improve customer satisfaction. Additionally, the presence of high-priced, low-rated products could indicate potential misalignment between pricing and perceived value.</li>
# </ol>

# %% [markdown]
# ### Plot histogram of ratings

# %%
plt.figure(figsize=(8,6))
plt.hist(df2['rating'], bins=10, color='orange', edgecolor='black')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>Frequency Peaks at Higher Ratings:</b> The graph shows a significant concentration of ratings around 4.0 to 4.5, with the highest frequency occurring around 4.5. This indicates that most products receive favorable ratings from consumers.</li>
#     <li><b>Low Ratings Are Rare:</b> Ratings below 3.0 are infrequent, suggesting that consumers generally avoid giving low ratings. This may indicate a higher level of satisfaction with products.</li>
#     <li><b>Gradual Increase to Moderate Ratings:</b> The frequency increases gradually from 1.0 to 3.5, indicating a moderate level of ratings in this range, but it peaks sharply after reaching 4.0.</li>
#     <li><b>Right Skewed Distribution:</b> The distribution is right-skewed, with a majority of ratings clustered at the higher end. Very few products receive ratings close to the minimum (1.0 and 2.0).</li>
#     <li><b>Implications for Quality Perception:</b> The high number of ratings at the top end suggests that consumers perceive most available products as good to excellent, which may reflect positively on the overall quality offered in the market.</li>
#     <li><b>Opportunities for Improvement:</b> Although the majority of ratings are high, the presence of lower ratings indicates there are still areas where some products could improve to enhance customer satisfaction.</li>
# </ol>

# %% [markdown]
# ### Count the number of products for  top 15 brands

# %%
brand_counts = df2['brand'].value_counts().head(15)
# Plotting the number of products per brand
plt.figure(figsize=(12,6))
brand_counts.plot(kind='bar', color='pink')
plt.title('Number of Products per Brand')
plt.xlabel('Brand')
plt.ylabel('Number of Products')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>Dominance of Fresho:</b> Fresho clearly stands out as the leading brand with over 600 products, significantly outpacing all other brands in terms of inventory. This suggests a strong market presence and diverse product offerings.</li>
#     <li><b>Strong Competitors:</b> Brands such as BB Royal and BB Home follow, with each having a substantial number of products (around 400 and 300, respectively). These brands also have a significant presence in the market, but they're still far behind Fresho.</li>
#     <li><b>Moderate Product Counts:</b> Brands like DP, Fresh Signature, and BB Combo have product counts ranging from about 200 to 250. This indicates a moderate level of market participation, suggesting these brands may focus on specific niches or categories.
#
# </li>
#     <li><b>Lower Representation:</b> Brands such as Amul, INATUR, Himalaya, and Dabur show product numbers around 100 to 200. While these brands are recognizable, their current product counts reflect a more limited focus compared to the top competitors.</li>
#     <li><b>Minimal Offerings Among Others:</b> Several brands, including GoodDiet, Cello, Nike, Iveo, and BIOTIQUE, have fewer than 100 products listed. This may imply either a recent entry into the market or a strategy focused on a smaller range of highly specialized products.</li>
#     <li><b>Market Implications:</b> The stark difference in product counts suggests that Fresho's extensive range may provide a competitive advantage, potentially attracting a wider customer base. Conversely, smaller brands may need to assess their product strategies to increase visibility and market share.</li>
# </ol>

# %% [markdown]
# ### Count the number of products for top 15 sub-category

# %%
sub_category_counts = df2['sub_category'].value_counts().head(15)

# Plotting the number of products per sub-category as a pie chart
plt.figure(figsize=(12,6))
sub_category_counts.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=90)
plt.title('Number of Products per Sub-Category')
plt.ylabel('')  # Hides the 'sub-category' label
plt.show()

# %% [markdown]
# <h2>FINDINGS</h2>

# %% [markdown]
# <ol>
#     <li><b>Skin Care Dominance:</b> The skin care sub-category leads with 16.1% of the total product offerings, indicating strong consumer interest and demand in this area.</li>
#     <li><b>Health & Medicine:</b> Following skin care, health and medicine products represent 7.9% of the total, suggesting a significant but lesser focus on health-related items compared to personal care.</li>
#     <li><b>Hair Care Products:</b> Hair care accounts for 7.2%, reflecting a solid market presence that indicates consumer awareness of and demand for hair products.</li>
#     <li><b>Balanced Representation in Other Categories:</b> Several sub-categories, including storage & accessories (7.1%), bath & hand wash (7.0%), and fragrances & deodorants (6.2%), each have around 6-7% of total offerings, suggesting a balanced and diverse range of products.</li>
#     <li><b>Moderate Numbers in Cooking Items:</b> The cooking-related categories, such as sauces, spreads & dips (4.6%), cooking & baking needs (4.7%), and snacks, dry fruits, and nuts (5.9%), show moderate representation, though less than personal care categories.
#
# </li>
#     <li><b>Lower Representation of Specialty Items:</b> Sub-categories like drinks & beverages (5.2%), masalas & spices (6.2%), and crockery & cutlery (6.0%) have lower percentages, indicating these categories may be niche markets with less extensive product offerings.</li>
#     <li><b>Room for Expansion:</b> The distribution suggests that while personal care dominates, there may be opportunities for brands to expand their offerings in cooking, specialty food items, and other less-represented sub-categories to capture more market share.</li>
# </ol>

# %% [markdown]
# <h1>Key Insights<h1>

# %% [markdown]
# <ol>
#     <li><h4>Product Categories:</h4>
#         <ul>
#             <li><b>Dominant Categories:</b> Beauty & Hygiene leads with the highest product count, followed by Kitchen, Garden & Pets.</li>
#             <li><b>Underserved Categories:</b> Beverages and Baby Care have fewer products, suggesting opportunities for expansion.</li>
#         </ul>
#     </li>
#     <li><h4>Top-Selling Products:</h4>
#         <ul>
#             <li><b>Customer Favorites:</b> Turmeric Powder and Cow Ghee are top-selling items, indicating strong demand for everyday essentials.</li>
#             <li><b>Recommendation:</b> Focus on promotions and inventory management for these high-demand items to boost revenue.</li>
#         </ul>
#     </li>
#     <li><h4>Popular Brands:</h4>
#         <ul>
#             <li><b>In-House Success:</b> bb Royal and BB Home dominate sales, showing strong customer trust in BigBasket's own brands.</li>
#             <li><b>Trusted External Brands:</b> Amul and Himalaya also perform well, reflecting high market credibility.</li>
#         </ul>
#     </li>
#     <li><h4>Discounted Products:</h4>
#         <ul>
#             <li><b>Maximum Discounts:</b> Items like the Fruit & Vegetables Hand Juicer have discounts as high as 82%, effectively targeting price-conscious shoppers.</li>
#             <li><b>Recommendation:</b> Use these high-discount products in marketing campaigns to attract budget-sensitive customers.</li>
#         </ul>
#     </li>
#     <li><h4>Product Ratings:</h4>
#         <ul>
#             <li><b>Highly Rated Products:</b> Face Wash and Veggie Cutter are among the top-rated items, reflecting customer satisfaction.</li>
#             <li><b>Recommendation:</b> Promote these products to enhance BigBasket’s brand perception.</li>
#             <li><b>Low-Rated Products:</b> Products like Aqua Halo Rejuvenating Conditioner have lower ratings, pointing to potential quality concerns.</li>
#             <li><b>Recommendation:</b> Address quality issues and improve reviews for poorly rated products.</li>
#         </ul>
#     </li>
#     <li><h4>Pricing Strategy:</h4>
#         <ul>
#             <li><b>Luxury Segment:</b> High-priced items, such as perfumes, cater to niche markets.</li>
#             <li><b>Recommendation:</b> Regularly benchmark against competitors to ensure prices align with customer expectations while maintaining margins.</li>
#         </ul>
#     </li>
#     <li><h4>Brand Ratings:</h4>
#         <ul>
#             <li><b>Top-Rated Brands:</b> Brands like 1mg and 6 Rasa excel with high average ratings, building customer trust.</li>
#             <li><b>Low-Rated Brands:</b> Require quality or service enhancements to improve customer perception.</li>
#             <li><b>Recommendation:</b> Prioritize quality checks and customer feedback for these brands.</li>
#         </ul>
#     </li>
#
# </ol>

# %% [markdown]
# <h1>Recommendations<h1>

# %% [markdown]
# <ol>
#     <li><h4>Product Promotions and Targeting:</h4>
#         <ul>
#             <li>Focus on promoting top-selling or high-margin products during peak seasons.</li>
#             <li>Offer tailored discounts or loyalty programs based on segmented customer groups.</li>
#         </ul>
#     </li>
#     <li><h4>Inventory Management:</h4>
#         <ul>
#             <li>Optimize stock levels for high-demand items to prevent shortages.</li>
#             <li>Regularly review and phase out low-demand products to reduce holding costs.</li>
#         </ul>
#     </li>
#     <li><h4>Sales Channels:</h4>
#         <ul>
#             <li>Expand delivery services to underperforming regions showing potential growth.</li>
#             <li>Improve mobile or web app user experience to increase conversion rates.</li>
#         </ul>
#     </li>
#     <li><h4>Customer Retention:</h4>
#         <ul>
#             <li>Introduce referral programs or special discounts for repeat customers.</li>
#             <li>Engage with customers through personalized recommendations or email campaigns.
# </li>
#         </ul>
#     </li>
#     <li><h4>Data Utilization:</h4>
#         <ul>
#             <li>Leverage predictive models to forecast demand and plan inventory accordingly.</li>
#             <li>Continuously update data collection methods to enhance analysis accuracy.</li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ## <u> **Conclusion** </u>

# %% [markdown]
# The analysis highlights critical patterns in customer preferences, operational bottlenecks, and inventory flow, providing actionable insights to streamline BigBasket's e-commerce operations. These findings will enable better resource allocation, reduced wastage, and an improved shopping experience for customers.
